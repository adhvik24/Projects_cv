# %%
# import
import cv2
import numpy as np
from matplotlib import pyplot as plt
import PIL
import os

# %%
files = os.listdir('FLIR_ADAS_1_3/train/RGB')
n = len(files)
files_ther = []
jpg = ['jpg']*n
zip_object = zip(files,jpg)
for list1_i, list2_i in zip_object:
    files_ther.append(list1_i.replace(list2_i,'')+'jpeg')
print(files_ther)

# %%
imgpath = os.path.join('FLIR_ADAS_1_3/train/thermal_8_bit',files_ther[0])

# %%
print(imgpath)
# Out:
# FLIR_ADAS_1_3/train/thermal_8_bit/FLIR_04323.jpeg

# %%
img = cv2.imread(imgpath)

# %%
img.shape
# Out:
# (512, 640, 3)

# %%
plt.imshow(img.squeeze())
